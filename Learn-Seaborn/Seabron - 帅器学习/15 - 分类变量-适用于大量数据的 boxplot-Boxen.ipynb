# %% [markdown]
# ## 适用于大量数据的箱线图 Boxen

# %% [markdown]
# 对于小型数据集(n < 200)，对于四分位数之外的尾部可能不值得信任，因此箱线图提供在四分位数之外提供较少的信息，并且异常值的数量通常小于10。但对于较大的数据集(10,000 < n < 100,000)，传统的箱线图不显示关于尾部的这些信息，可以为它们绘制箱线图的增强版，提供超过四分位数的更精确估计

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 这个图最初被称为`letter value`(字母值)，因为它显示了大量被称为`字母值`的分位数。
# 字母值是具有特定深度的从中位值开始递归定义的一系列值
