# %% [markdown]
# + plt.xlabel()  -- 对`X`轴增加文本标签
# + plt.ylabel()  -- 对`Y`轴增加文本标签
# + plt.title()   -- 对图形整体增加文本标签
# + plt.text()    -- 在任意位置增加文本
# + plt.annotate()  -- 在图形中增加带箭头的注解

# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.arange(0.0, 5.0, 0.02)
plt.plot(a, np.cos(2*np.pi*a), 'r--')

plt.xlabel('Time', fontproperties='DejaVu Sans', fontsize=15, color='green')
plt.ylabel('Value', fontproperties='DejaVu Sans', fontsize=15)
plt.title('Instance $y=cos(2\pi x)$', fontproperties='DejaVu Sans', fontsize=25)
plt.text(2, 1, r'$\mu=100$', fontsize=15)

plt.axis([-1, 6, -2, 2])
plt.grid(True)                 # 增加网格线
plt.show()
