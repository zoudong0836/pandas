# %% [markdown]
# # 数据的预处理

# %% [markdown]
# ## 数据的审核

# %% [markdown]
# **数据审核** 是检查数据中是否有错误。
# > 对于通过调查取得的原始数据，主要从完整性和准确性两个方面去审核
# > 对于二手数据，应着重审核数据的适用性和时效性
#
# + 完整性审核：主要是检查应调查的单位或个体是否有遗漏，所有的调查项目是否填写齐全等
# + 准确性审核：主要是检查数据是否有错误，是否存在异常值等
# + 适用性审核：主要是弄清楚数据的来源、数据的口径以及有关的背景材料，以便确定这些数据是否符合分析研究的需要，不能盲目生搬硬套
# + 时效性审核：主要是指保证数据的及时性，如果取得的数据过于滞后，就可能失去研究的意义

# %% [markdown]
# ## 数据的筛选

# %% [markdown]
# > 数据筛选是根据需要找出符合特定条件的某类数据

# %% [markdown]
# ## 数据的排序

# %% [markdown]
# > 数据排序是按一定顺序将数据排列，以便研究者通过浏览数据发现一些明显的特征或趋势，找到解决问题的线索
# > 排序还有助于对数据检查纠错，以及为重新归类或分组提供方便

# %% [markdown]
# # 品质数据的整理与展示
#
# + 对品质数据主要做分类整理 (品质数据包括分类数据和顺序数据)
# + 对数值型数据主要做分组整理

# %% [markdown]
# ## 分类数据的整理与图示

# %% [markdown]
# ### 频数与频数分布
#
# + 频数：落在某一特定类别或组中的数据个数
# + 比例：也称构成比，它是一个样本或总体中各个部分的数据与全部数据之比，通常用于反映样本或总体的构成或结构
# + 百分比：将比例乘以100得到的数值，用%表示
# + 比率：样本或总体中不同类别数据之间的比值，由于比率不是部分与整体之间的对比关系，因此比值可能大于1

# %% [markdown]
# ### 分类数据的图示

# %% [markdown]
# + 条形图（bar chart）：用宽度相同的条形的高度或长短来表示数据的多少的图形，纵置时也称为柱形图（column chart），此外，又分简单条形图、复杂条形图等，主要用于反映分类数据的频数分布
#
# ![image.png](attachment:image.png)

# %% [markdown]
# + 帕累托图（Pareto chart）：按各类别数据出现的频数多少排序后绘制的条形图，左侧纵轴给出计数值，即频数，右侧的纵轴给出累积百分比
#
# ![image.png](attachment:image.png)

# %% [markdown]
# + 饼图（pie chart）：用圆形及园内扇形的角度来表示数值大小的图形，它主要用于表示一个样本或总体中各组成部分的数据占全部数据的比例，对研究结构性问题十分有用。绘制圆形图时，样本或总体中各部分所占的百分比用园内的各个扇形角度表示，这些扇形的中心角度，按各部分数据百分比乘以360度确定
#
# ![image.png](attachment:image.png)

# %% [markdown]
# + 环形图：把饼图叠在一起，挖取中间部分即可。环形图中间有一个"空洞"，样本或总体中的每一部分数据用环中的一段表示，与饼图类似，但又有区别：
# > + 饼图只能显示一个总体各部分所占的比例
# > + 环形图则可以同时绘制多个样本或总体的数据系列，每一个样本或总体的数据系列为一个环；用于结构比较研究
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 顺序数据的整理与图示

# %% [markdown]
# ### 累积频数与累积频率
#
# + 累积频数（cumulative frequencies）：将各有序类别或组的频数逐级累加起来得到的频数
#
# > 频数的累积方法：
# > + 从类别顺序的开始一方向类别顺序的最后一方累加频数（数值型分组数据则是从变量值小的一方向变量值大的一方累加频数），称为向上累积
# > + 从类别顺序的最后一方向类别顺序的开始一方累加频数（数值型分组数据则是从变量值大的一方向变量值小的一方累加频数），称为向下累积
#
# + 累积频率或累积百分比（cumulative percentages）：将各有序类别或组的百分比逐级累加，它也有向上累积和向下累积两种方法

# %% [markdown]
# # 数值型数据的整理与展示

# %% [markdown]
# ## 数据分组
# > 根据统计研究的需要，将原始数据按照某种标准分成不同的组别，分组后的数据称为"分组数据"
#
# 数据分组的方法：
# + 单变量值分组：把每一个变量值作为一组；该方法只适用于变量值较少的离散型变量
# + 组距分组

# %% [markdown]
# 组距分组：
# + 将变量值的一个区间作为一组
# + 适合于连续变量
# + 适合于变量值较多的情况
# + 需要遵循"不重不漏"的原则
# + 可采用等距分组，也可采用不等距分组

# %% [markdown]
# 分组和编制频数分布表的步骤：
# + 确定组数： 一般情况下，一组数据所分的组数不应少于5组且不多于15组，即 $5 \leq K \leq 15$
# + 确定各组组距：组距可以根据全部数据的最大值和最小值及所分的组数来确定，组距 = （最大值 - 最小值）/ 组数
# + 根据分组数据整理成频数分布表

# %% [markdown]
# 组距分组（几个概念）
# + 下限（lower limit）：一个组的最小值
# + 上限（upper limit）：一个组的最大值
# + 组距（class width）：上限与下限之差
# + 组中值（class midpoint）：下限与上限之间的中点值
# $$ 组中值 = \frac{下限值 + 上限制}{2} $$

# %% [markdown]
# ## 数值型数据的图示

# %% [markdown]
# ### 分组数据：直方图（histogram）
# > 用于展示分组数据分布的一种图形，用矩形的宽度和高度（即面积）来表示频数分布的
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 直方图与条形图的区别：
# + 条形图是用条形的长度（横置时）表示各类别频数的多少，其宽度（表示类别）则是固定的
# + 直方图是用面积表示各组频数的多少，矩形的高度表示每一组的频数或频率，宽度则表示各组的组距，因此其高度与宽度均有意义
# + 由于分组数据具有连续性，直方图的各矩形通常是连续排列，而条形图则是分开排列
# + 条形图主要用于展示分类数据，而直方图则主要用于展示数值型数据

# %% [markdown]
# ### 未分组数据：茎叶图（stem-and-leaf display）
# > + 茎叶图：反应原始数据分布的图形，它由`茎`和`叶`两部分构成，其图形是由数字组成的。通过茎叶图，可以看出数据分布的形状及数据的离散状况。比如：分布是否对称，数据是否集中，是否由离群点等
# > + 绘制方法：首先把一个数字分成两部分，通常是以该组数据的高位数值作为树茎，而叶子上只保留该数值的最后一个数字
# > + 茎叶图与直方图的区别：茎叶图既能给出数据的分布状况，又能给出每一个原始数值，保留了原始数据的信息。而直方图虽然能很好的显示数据的分布，但不能保留原始的数据
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 未分组数据：箱线图（box plot）
# > + 箱线图：由一组数据的最大值、最小值、中位数、两个四分位数这5个特征值绘制而成，它主要用于反映原始数据分布的特征，还可以进行多组数据分布特征的比较
# > + 绘制方法：先找出一组数据的最大值、最小值、中位数、两个四分位数据；然后连接两个四分位数画出箱子；再将最大值和最小值与箱子相连接，中位数在箱子中间
# > + 箱线图分布类型：1)对称分布、2)左偏分布、3)右偏分布、4)U形分布
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 时间序列数据：线图（line plot）
# > + 时间序列数据：在不同时间上获得的数值型数据
# > + 线图：主要用于反映现象随时间变化的特征，主要适用于时间序列数据图形的绘制
# > + 绘制方法：绘制图形时，时间一般绘制在横轴，观测值绘制在纵轴
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 多变量数据的图示

# %% [markdown]
# ### 散点图（scatter diagram）
# > 用二维坐标展示两个变量之间关系的一种图形，由坐标及其散点形成的二维数据图
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 气泡图（bubble chart）
# > 用于展示三个变量之间的关系，将一个变量放在横轴，另一个变量放在纵轴，第三个变量用气泡大小来表示
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 雷达图（radar chart）
# > 显示多个变量的常用图示方法，也成为蜘蛛图。在显示或对比各变量的数值总和时十分有用。雷达图也可以研究多个样本之间的相似程度

# %% [markdown]
# ## 总结
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 合理使用图表
